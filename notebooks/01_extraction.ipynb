# %% [markdown]
# # 01 — Extraction (template)
#
# Goal: load raw dataset(s) from `data/raw/`, inspect schema, and document initial assumptions.
#
# - Input: `data/raw/...`
# - Output: a quick schema/profile summary and a **confirmed grain** (what 1 row means)

# %%
from pathlib import Path

import pandas as pd

RAW_DIR = Path("../data/raw").resolve()
RAW_DIR

# %%
# TODO: Replace with your actual raw filename(s)
raw_files = sorted([p for p in RAW_DIR.glob("**/*") if p.is_file() and not p.name.startswith(".")])
raw_files[:10]

# %%
# Example: load a CSV once you add it
# df = pd.read_csv(RAW_DIR / "dataset.csv")
# df.head()

# %%
# Basic profiling template
# df.shape, df.dtypes
# df.isna().mean().sort_values(ascending=False).head(20)
# df.describe(include="all").T.head(20)
