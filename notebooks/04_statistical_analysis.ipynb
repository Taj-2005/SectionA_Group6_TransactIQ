# %% [markdown]
# # 04 — Statistical analysis (template)
#
# Goal: quantify relationships that support decisions (hypothesis tests, regression, segmentation).
#
# Examples:
# - A/B or cohort comparisons (t-test / Mann–Whitney)
# - Categorical association (chi-square)
# - Simple regression for driver analysis
# - Confidence intervals and practical significance

# %%
from pathlib import Path

import numpy as np
import pandas as pd

PROCESSED_DIR = Path("../data/processed").resolve()

# df = pd.read_csv(PROCESSED_DIR / "cleaned.csv")
# df.head()

# %%
# TODO: implement tests/models
pass
