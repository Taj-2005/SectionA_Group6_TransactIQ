# %% [markdown]
# # 03 — EDA (template)
#
# Goal: explore distributions, trends, segments, and potential KPI drivers.
#
# - Load cleaned data from `data/processed/`
# - Validate assumptions (grain, keys)
# - Identify outliers and data quality gaps
# - Produce stakeholder-friendly insights

# %%
from pathlib import Path

import pandas as pd

PROCESSED_DIR = Path("../data/processed").resolve()

# df = pd.read_csv(PROCESSED_DIR / "cleaned.csv")
# df.head()

# %%
# TODO: add EDA plots and tables (keep notebook reproducible)
pass
