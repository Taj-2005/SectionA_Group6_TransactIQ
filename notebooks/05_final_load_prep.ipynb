# %% [markdown]
# # 05 — Final load prep for Tableau (template)
#
# Goal: shape stable, Tableau-friendly datasets with a clear grain and consistent dimensions/measures.
#
# Outputs (recommended):
# - `data/processed/tableau_fact.csv`
# - `data/processed/tableau_kpis.csv` (or a single wide KPI table)

# %%
from pathlib import Path

import pandas as pd

PROCESSED_DIR = Path("../data/processed").resolve()

# df = pd.read_csv(PROCESSED_DIR / "cleaned.csv")
# df.head()

# %%
# TODO: aggregate/reshape to your Tableau grain
# tableau_fact = ...
# tableau_fact.to_csv(PROCESSED_DIR / "tableau_fact.csv", index=False)
pass
